# %% [markdown]
# # Offenses' relationship with month

# %%
import collections
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Note that one incident could have up to 10 offense record
incidentDF = pd.read_csv("PA-2016/nibrs_incident.csv")
offenseDF = pd.read_csv("PA-2016/nibrs_offense.csv")
offenseTypeDF = pd.read_csv("PA-2016/nibrs_offense_type.csv")

# For relationship analysis
victimDF = pd.read_csv("PA-2016/nibrs_victim.csv")
offenderDF = pd.read_csv("PA-2016/nibrs_offender.csv")
victimTypeDF = pd.read_csv("PA-2016/nibrs_victim_type.csv")
ethnicityDF = pd.read_csv("PA-2016/nibrs_ethnicity.csv")
relationshipDF = pd.read_csv("PA-2016/nibrs_relationship.csv")
victimOffenderRelDF = pd.read_csv("PA-2016/nibrs_victim_offender_rel.csv")
ageDF = pd.read_csv("PA-2016/nibrs_age.csv")
locationTable = pd.read_csv("PA-2016/nibrs_location_type.csv")

# Criminal acts
criminalActDF = pd.read_csv("PA-2016/nibrs_criminal_act.csv")
criminalActTypeDF = pd.read_csv("PA-2016/nibrs_criminal_act_type.csv")

# bias of the offense
biasMotivationDF = pd.read_csv("PA-2016/nibrs_bias_motivation.csv")
biasListDF = pd.read_csv("PA-2016/nibrs_bias_list.csv")

# for month mapping
monthDF = pd.read_csv("PA-2016/nibrs_month.csv")

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.replace.html
# https://stackoverflow.com/questions/20250771/remap-values-in-pandas-column-with-a-dict
# Replace a col with a specified mapping dict.
locationMapping = dict(zip(locationTable["location_id"], locationTable["location_name"]))
offenseTypeMapping = dict(zip(offenseTypeDF["offense_type_id"], offenseTypeDF["offense_name"]))
victimTypeMapping = dict(zip(victimTypeDF["victim_type_id"], victimTypeDF["victim_type_name"]))
relationshipMapping = dict(zip(relationshipDF["relationship_id"], relationshipDF["relationship_name"]))
criminalActTypeMapping = dict(zip(criminalActTypeDF["criminal_act_id"], criminalActTypeDF["criminal_act_name"]))
monthMapping = dict(zip(monthDF["nibrs_month_id"], monthDF["month_num"]))

# %%
offenseDF.replace({"location_id": locationMapping, "offense_type_id": offenseTypeMapping},
                 inplace = True)


incidentDF.replace({"nibrs_month_id": monthMapping}, inplace=True)
incOffenseJoinedDF = offenseDF.merge(right=incidentDF, how="inner", on="incident_id")
# len(incOffenseJoinedDF)
cleanedIncOffJoined = incOffenseJoinedDF[["offense_id", "incident_id", "offense_type_id", "attempt_complete_flag"
                                         , "location_id", "nibrs_month_id", "incident_date", "incident_hour"]]
cleanedIncOffJoined.head()
# Out:
#    offense_id  incident_id            offense_type_id attempt_complete_flag  \
# 0    91124963     83457465        Theft From Building                     C
# 1    91124972     83457473  Drug Equipment Violations                     C
# 2    91618994     83886692             Simple Assault                     C
# 3    92509421     84661377  Drug Equipment Violations                     C
# 4    92508047     84661375             Simple Assault                     C
#
#           location_id  nibrs_month_id        incident_date  incident_hour
# 0      Residence/Home               1  2016-01-25 00:00:00             16
# 1   Highway/Road/Ally               1  2016-01-28 00:00:00             20
# 2  Parking Lot/Garage               2  2016-02-27 00:00:00             16
# 3      Residence/Home               4  2016-04-24 00:00:00             13
# 4      Residence/Home               5  2016-05-28 00:00:00              6

# %%
grouped = cleanedIncOffJoined.groupby(by = ["offense_type_id", "nibrs_month_id"])
# Out:
# array([('Aggravated Assault', 1), ('Aggravated Assault', 2),
#        ('Aggravated Assault', 3), ('Aggravated Assault', 4),
#        ('Aggravated Assault', 5), ('Aggravated Assault', 6),
#        ('Aggravated Assault', 7), ('Aggravated Assault', 8),
#        ('Aggravated Assault', 9), ('Aggravated Assault', 10),
#        ('Aggravated Assault', 11), ('Aggravated Assault', 12),
#        ('All Other Larceny', 1), ('All Other Larceny', 2),
#        ('All Other Larceny', 3), ('All Other Larceny', 4),
#        ('All Other Larceny', 5), ('All Other Larceny', 6),
#        ('All Other Larceny', 7), ('All Other Larceny', 8),
#        ('All Other Larceny', 9), ('All Other Larceny', 10),
#        ('All Other Larceny', 11), ('All Other Larceny', 12), ('Arson', 1),
#        ('Arson', 2), ('Arson', 5), ('Arson', 7), ('Arson', 8),
#        ('Arson', 9), ('Arson', 10), ('Arson', 11),
#        ('Assisting or Promoting Prostitution', 7),
#        ('Assisting or Promoting Prostitution', 12),
#        ('Burglary/Breaking & Entering', 1),
#        ('Burglary/Breaking & Entering', 2),
#        ('Burglary/Breaking & Entering', 3),
#        ('Burglary/Breaking & Entering', 4),
#        ('Burglary/Breaking & Entering', 5),
#        ('Burglary/Breaking & Entering', 6),
#        ('Burglary/Breaking & Entering', 7),
#        ('Burglary/Breaking & Entering', 8),
#        ('Burglary/Breaking & Entering', 9),
#        ('Burglary/Breaking & Entering', 10),
#        ('Burglary/Breaking & Entering', 11),
#        ('Burglary/Breaking & Entering', 12),
#        ('Counterfeiting/Forgery', 1), ('Counterfeiting/Forgery', 2),
#        ('Counterfeiting/Forgery', 3), ('Counterfeiting/Forgery', 4),
#        ('Counterfeiting/Forgery', 5), ('Counterfeiting/Forgery', 6),
#        ('Counterfeiting/Forgery', 7), ('Counterfeiting/Forgery', 8),
#        ('Counterfeiting/Forgery', 9), ('Counterfeiting/Forgery', 10),
#        ('Counterfeiting/Forgery', 11), ('Counterfeiting/Forgery', 12),
#        ('Credit Card/Automated Teller Machine Fraud', 1),
#        ('Credit Card/Automated Teller Machine Fraud', 2),
#        ('Credit Card/Automated Teller Machine Fraud', 3),
#        ('Credit Card/Automated Teller Machine Fraud', 4),
#        ('Credit Card/Automated Teller Machine Fraud', 5),
#        ('Credit Card/Automated Teller Machine Fraud', 6),
#        ('Credit Card/Automated Teller Machine Fraud', 7),
#        ('Credit Card/Automated Teller Machine Fraud', 8),
#        ('Credit Card/Automated Teller Machine Fraud', 9),
#        ('Credit Card/Automated Teller Machine Fraud', 10),
#        ('Credit Card/Automated Teller Machine Fraud', 11),
#        ('Credit Card/Automated Teller Machine Fraud', 12),
#        ('Destruction/Damage/Vandalism of Property', 1),
#        ('Destruction/Damage/Vandalism of Property', 2),
#        ('Destruction/Damage/Vandalism of Property', 3),
#        ('Destruction/Damage/Vandalism of Property', 4),
#        ('Destruction/Damage/Vandalism of Property', 5),
#        ('Destruction/Damage/Vandalism of Property', 6),
#        ('Destruction/Damage/Vandalism of Property', 7),
#        ('Destruction/Damage/Vandalism of Property', 8),
#        ('Destruction/Damage/Vandalism of Property', 9),
#        ('Destruction/Damage/Vandalism of Property', 10),
#        ('Destruction/Damage/Vandalism of Property', 11),
#        ('Destruction/Damage/Vandalism of Property', 12),
#        ('Drug Equipment Violations', 1), ('Drug Equipment Violations', 2),
#        ('Drug Equipment Violations', 3), ('Drug Equipment Violations', 4),
#        ('Drug Equipment Violations', 5), ('Drug Equipment Violations', 6),
#        ('Drug Equipment Violations', 7), ('Drug Equipment Violations', 8),
#        ('Drug Equipment Violations', 9),
#        ('Drug Equipment Violations', 10),
#        ('Drug Equipment Violations', 11),
#        ('Drug Equipment Violations', 12), ('Drug/Narcotic Violations', 1),
#        ('Drug/Narcotic Violations', 2), ('Drug/Narcotic Violations', 3),
#        ('Drug/Narcotic Violations', 4), ('Drug/Narcotic Violations', 5),
#        ('Drug/Narcotic Violations', 6), ('Drug/Narcotic Violations', 7),
#        ('Drug/Narcotic Violations', 8), ('Drug/Narcotic Violations', 9),
#        ('Drug/Narcotic Violations', 10), ('Drug/Narcotic Violations', 11),
#        ('Drug/Narcotic Violations', 12), ('Embezzlement', 1),
#        ('Embezzlement', 5), ('Embezzlement', 7), ('Embezzlement', 8),
#        ('Embezzlement', 10), ('Embezzlement', 11), ('Embezzlement', 12),
#        ('Extortion/Blackmail', 5), ('Extortion/Blackmail', 11),
#        ('False Pretenses/Swindle/Confidence Game', 1),
#        ('False Pretenses/Swindle/Confidence Game', 2),
#        ('False Pretenses/Swindle/Confidence Game', 3),
#        ('False Pretenses/Swindle/Confidence Game', 4),
#        ('False Pretenses/Swindle/Confidence Game', 5),
#        ('False Pretenses/Swindle/Confidence Game', 6),
#        ('False Pretenses/Swindle/Confidence Game', 7),
#        ('False Pretenses/Swindle/Confidence Game', 8),
#        ('False Pretenses/Swindle/Confidence Game', 9),
#        ('False Pretenses/Swindle/Confidence Game', 10),
#        ('False Pretenses/Swindle/Confidence Game', 11),
#        ('False Pretenses/Swindle/Confidence Game', 12), ('Fondling', 1),
#        ('Fondling', 2), ('Fondling', 3), ('Fondling', 4), ('Fondling', 5),
#        ('Fondling', 7), ('Fondling', 8), ('Fondling', 9),
#        ('Fondling', 10), ('Fondling', 11), ('Fondling', 12),
#        ('Impersonation', 1), ('Impersonation', 2), ('Impersonation', 3),
#        ('Impersonation', 4), ('Impersonation', 5), ('Impersonation', 6),
#        ('Impersonation', 7), ('Impersonation', 8), ('Impersonation', 9),
#        ('Impersonation', 10), ('Impersonation', 11),
#        ('Impersonation', 12), ('Intimidation', 1), ('Intimidation', 2),
#        ('Intimidation', 3), ('Intimidation', 4), ('Intimidation', 5),
#        ('Intimidation', 6), ('Intimidation', 7), ('Intimidation', 8),
#        ('Intimidation', 9), ('Intimidation', 10), ('Intimidation', 11),
#        ('Intimidation', 12), ('Kidnapping/Abduction', 4),
#        ('Kidnapping/Abduction', 5), ('Kidnapping/Abduction', 6),
#        ('Kidnapping/Abduction', 9), ('Kidnapping/Abduction', 10),
#        ('Kidnapping/Abduction', 12), ('Motor Vehicle Theft', 1),
#        ('Motor Vehicle Theft', 2), ('Motor Vehicle Theft', 3),
#        ('Motor Vehicle Theft', 4), ('Motor Vehicle Theft', 5),
#        ('Motor Vehicle Theft', 6), ('Motor Vehicle Theft', 7),
#        ('Motor Vehicle Theft', 8), ('Motor Vehicle Theft', 9),
#        ('Motor Vehicle Theft', 10), ('Motor Vehicle Theft', 11),
#        ('Motor Vehicle Theft', 12),
#        ('Murder and Nonnegligent Manslaughter', 3),
#        ('Murder and Nonnegligent Manslaughter', 4),
#        ('Murder and Nonnegligent Manslaughter', 5),
#        ('Murder and Nonnegligent Manslaughter', 6),
#        ('Murder and Nonnegligent Manslaughter', 9),
#        ('Murder and Nonnegligent Manslaughter', 12),
#        ('Negligent Manslaughter', 8), ('Pocket-picking', 3),
#        ('Pocket-picking', 5), ('Pocket-picking', 6),
#        ('Pocket-picking', 7), ('Pocket-picking', 9),
#        ('Pocket-picking', 12), ('Pornography/Obscene Material', 1),
#        ('Pornography/Obscene Material', 3),
#        ('Pornography/Obscene Material', 8),
#        ('Pornography/Obscene Material', 10),
#        ('Pornography/Obscene Material', 11), ('Prostitution', 10),
#        ('Purse-snatching', 4), ('Purse-snatching', 10), ('Rape', 1),
#        ('Rape', 2), ('Rape', 3), ('Rape', 4), ('Rape', 5), ('Rape', 6),
#        ('Rape', 7), ('Rape', 8), ('Rape', 9), ('Rape', 10), ('Rape', 11),
#        ('Rape', 12), ('Robbery', 1), ('Robbery', 2), ('Robbery', 3),
#        ('Robbery', 4), ('Robbery', 5), ('Robbery', 6), ('Robbery', 7),
#        ('Robbery', 8), ('Robbery', 9), ('Robbery', 10), ('Robbery', 11),
#        ('Robbery', 12), ('Sexual Assault With An Object', 1),
#        ('Sexual Assault With An Object', 3),
#        ('Sexual Assault With An Object', 4),
#        ('Sexual Assault With An Object', 5),
#        ('Sexual Assault With An Object', 8),
#        ('Sexual Assault With An Object', 12), ('Shoplifting', 1),
#        ('Shoplifting', 2), ('Shoplifting', 3), ('Shoplifting', 4),
#        ('Shoplifting', 5), ('Shoplifting', 6), ('Shoplifting', 7),
#        ('Shoplifting', 8), ('Shoplifting', 9), ('Shoplifting', 10),
#        ('Shoplifting', 11), ('Shoplifting', 12), ('Simple Assault', 1),
#        ('Simple Assault', 2), ('Simple Assault', 3),
#        ('Simple Assault', 4), ('Simple Assault', 5),
#        ('Simple Assault', 6), ('Simple Assault', 7),
#        ('Simple Assault', 8), ('Simple Assault', 9),
#        ('Simple Assault', 10), ('Simple Assault', 11),
#        ('Simple Assault', 12), ('Sodomy', 1), ('Sodomy', 3),
#        ('Sodomy', 6), ('Sodomy', 7), ('Sodomy', 8), ('Sodomy', 9),
#        ('Sodomy', 11), ('Statutory Rape', 1), ('Statutory Rape', 2),
#        ('Statutory Rape', 7), ('Statutory Rape', 8),
#        ('Statutory Rape', 12), ('Stolen Property Offenses', 1),
#        ('Stolen Property Offenses', 2), ('Stolen Property Offenses', 4),
#        ('Stolen Property Offenses', 5), ('Stolen Property Offenses', 6),
#        ('Stolen Property Offenses', 7), ('Stolen Property Offenses', 8),
#        ('Stolen Property Offenses', 9), ('Stolen Property Offenses', 10),
#        ('Stolen Property Offenses', 11), ('Stolen Property Offenses', 12),
#        ('Theft From Building', 1), ('Theft From Building', 2),
#        ('Theft From Building', 3), ('Theft From Building', 4),
#        ('Theft From Building', 5), ('Theft From Building', 6),
#        ('Theft From Building', 7), ('Theft From Building', 8),
#        ('Theft From Building', 9), ('Theft From Building', 10),
#        ('Theft From Building', 11), ('Theft From Building', 12),
#        ('Theft From Coin-Operated Machine or Device', 5),
#        ('Theft From Coin-Operated Machine or Device', 7),
#        ('Theft From Coin-Operated Machine or Device', 12),
#        ('Theft From Motor Vehicle', 1), ('Theft From Motor Vehicle', 2),
#        ('Theft From Motor Vehicle', 3), ('Theft From Motor Vehicle', 4),
#        ('Theft From Motor Vehicle', 5), ('Theft From Motor Vehicle', 6),
#        ('Theft From Motor Vehicle', 7), ('Theft From Motor Vehicle', 8),
#        ('Theft From Motor Vehicle', 9), ('Theft From Motor Vehicle', 10),
#        ('Theft From Motor Vehicle', 11), ('Theft From Motor Vehicle', 12),
#        ('Theft of Motor Vehicle Parts or Accessories', 1),
#        ('Theft of Motor Vehicle Parts or Accessories', 2),
#        ('Theft of Motor Vehicle Parts or Accessories', 3),
#        ('Theft of Motor Vehicle Parts or Accessories', 4),
#        ('Theft of Motor Vehicle Parts or Accessories', 5),
#        ('Theft of Motor Vehicle Parts or Accessories', 6),
#        ('Theft of Motor Vehicle Parts or Accessories', 7),
#        ('Theft of Motor Vehicle Parts or Accessories', 8),
#        ('Theft of Motor Vehicle Parts or Accessories', 9),
#        ('Theft of Motor Vehicle Parts or Accessories', 10),
#        ('Theft of Motor Vehicle Parts or Accessories', 11),
#        ('Theft of Motor Vehicle Parts or Accessories', 12),
#        ('Weapon Law Violations', 1), ('Weapon Law Violations', 2),
#        ('Weapon Law Violations', 3), ('Weapon Law Violations', 4),
#        ('Weapon Law Violations', 5), ('Weapon Law Violations', 6),
#        ('Weapon Law Violations', 7), ('Weapon Law Violations', 8),
#        ('Weapon Law Violations', 9), ('Weapon Law Violations', 10),
#        ('Weapon Law Violations', 11), ('Weapon Law Violations', 12)],
#       dtype=object)
